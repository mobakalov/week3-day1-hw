# %% [markdown]
# # Regular Expressions

# %% [markdown]
# # Tasks today:
#
# 1. <b>Importing</b> <br>
# 2. <b>Using Regular Expressions</b> <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; a) re.compile() <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; b) re.match() <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; c) re.findall() <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; d) re.search() <br>
# 3. <b>Sets</b> <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; a) Integer Ranges <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; b) Character Ranges <br>
# 4. <b>Counting Occurences</b> <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; a) {x} <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; b) {, x} <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; c) {?} <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; d) {\*} <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; e) {+} <br>
# 5. <b>In-Class Exercise #1</b> <br>
# 6. <b>Escaping Characters</b> <br>
# 7. <b>Grouping</b> <br>
# 8. <b>In-Class Exercise #2</b> <br>
# 9. <b>Opening a File</b> <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; a) open() <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; b) with open() <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; c) re.match() <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; d) re.search() <br>
#    &nbsp;&nbsp;&nbsp;&nbsp; e) Store the String in a Variable <br>
# 10. <b>Regex Project</b> <br>

# %% [markdown]
# ### Importing <br>
#
# <p>Regular Expressions are universal throughout most programming languages... They are generally imported through the module 're'.</p>

# %%
# import re
import re

# %% [markdown]
# ### Using Regular Expressions <br>
#
# <p>Regular expressions give us the ability to search for patterns within text, strings, files, etc. They serve several uses, such as; security measures, searching, filtering, pattern recognition, and more...</p>

# %% [markdown]
# ##### re.compile()

# %%
# using compile, predetermines the string to be used in regular expression methods
pattern = re.compile('bear')
print(type(pattern))

paragraph = '''Bears are carnivoran mammals of the family Ursidae. They are classified as caniforms, or doglike carnivorans. Although only eight species of bears are extant, they are widespread, appearing in a wide variety of habitats throughout the Northern Hemisphere and partially in the Southern Hemisphere. Bears are found on the continents of North America, South America, Europe, and Asia. Common characteristics of modern bears include large bodies with stocky legs, long snouts, small rounded ears, shaggy hair, plantigrade paws with five nonretractile claws, and short tails.

While the polar bear is mostly carnivorous, and the giant panda feeds almost entirely on bamboo, the remaining six species are omnivorous with varied diets. With the exception of courting individuals and mothers with their young, bears are typically solitary animals. They may be diurnal or nocturnal and have an excellent sense of smell. Despite their heavy build and awkward gait, they are adept runners, climbers, and swimmers. Bears use shelters, such as caves and logs, as their dens; most species occupy their dens during the winter for a long period of hibernation, up to 100 days.

Bears have been hunted since prehistoric times for their meat and fur; they have been used for bear-baiting and other forms of entertainment, such as being made to dance. With their powerful physical presence, they play a prominent role in the arts, mythology, and other cultural aspects of various human societies. In modern times, bears have come under pressure through encroachment on their habitats and illegal trade in bear parts, including the Asian bile bear market. The IUCN lists six bear species as vulnerable or endangered, and even least concern species, such as the brown bear, are at risk of extirpation in certain countries. The poaching and international trade of these most threatened populations are prohibited, but still ongoing.


'''
# Out:
# <class 're.Pattern'>

# %% [markdown]
# ##### re.match()

# %%
match = pattern.match(paragraph)
print(match)

# print(match.span())
# print(paragraph[0:4])
# Out:
# None

# %% [markdown]
# ##### re.findall()

# %%
found = pattern.findall(paragraph)
print(found)
print(len(found))
# Out:
# ['bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear']
# 10

# %% [markdown]
# ##### re.search()

# %%
search_match = pattern.search(paragraph)
print(search_match)
# my_span = search_match.span()
# paragraph[my_span[0]:my_span[1]]
# Out:
# <re.Match object; span=(141, 145), match='bear'>

# %% [markdown]
# ### Sets <br>
#
# <p>The following cells will allow you to use regular expressions to search for certain values within a range such as numbers 1 through 4.</p>

# %% [markdown]
# ##### [a-z] or [A-Z] - any lowercase/uppercase letters from a to z<br/>[^2] - anything that's not 2

# %% [markdown]
# ##### Integer Ranges

# %%
pat_int = re.compile('[0-7][7-9][0-3]')

found = pat_int.findall('21367852922318353721')
print(found)
# Out:
# ['292', '183', '372']

# %% [markdown]
# ##### Character Ranges

# %%
pat_char = re.compile('[A-Z][a-z]')
found = pat_char.findall('Hello There Mr. Anderson')
print(found)
# Out:
# ['He', 'Th', 'Mr', 'An']

# %% [markdown]
# ### Counting Occurences

# %% [markdown]
# ##### {x} - something that occurs {num_of_times}

# %%
pat1 = re.compile('s{3}')
found = pat1.findall('Hello there sssaid the sssssssnake')
print(found)
# Out:
# ['sss', 'sss', 'sss']

# %% [markdown]
# ##### {x, x} - something that occurs between x and x times

# %%
pat2 = re.compile('m{1,5}')
found = pat2.findall('This is an example of regex trying to find mmmmmmmore than one m, maybe this will work?')
print(found)
# Out:
# ['m', 'mmmmm', 'mm', 'm', 'm']

# %% [markdown]
# ##### ? - something that occurs 0 or 1 time

# %%
pat3 = re.compile('Mrs?')
found = pat3.findall('Hello Mr.Anderson! How is Mrs. Anderson and Ms.Anderson')
print(found)
# Out:
# ['Mr', 'Mrs']

# %% [markdown]
# ##### \* - something that occurs at least 0 times

# %%
pat4 = re.compile('Ms*')
found = pat4.findall('Hello Mr.Anderson! How is Mrs. Anderson and Ms.Anderson Ms M Mssssssssssss')
print(found)
# Out:
# ['M', 'M', 'Ms', 'Ms', 'M', 'Mssssssssssss']

# %% [markdown]
# ##### + - something that occurs at least once

# %%
pat5 = re.compile('Ms+')
found = pat5.findall('Hello Mr.Anderson! How is Mrs. Anderson and Ms.Anderson Ms M Mssssssssssss')
print(found)
# Out:
# ['Ms', 'Ms', 'Mssssssssssss']

# %% [markdown]
# ##### In-class exercise 1:
#
# Use a regular expression to find every number in the given string

# %%
my_string = "This string has 10909090 numbers, but it is only 1 string. I hope you solve this 2day."

# Output: ['10909090','1',2]

my_string_new = re.compile('[0-9]+')
found = my_string_new.findall(my_string)
print(found)
# Out:
# ['10909090', '1', '2']

# %% [markdown]
# ### Escaping Characters

# %% [markdown]
# ##### \w - look for any Unicode character<br/>\W - look for anything that isnt a Unicode character
#
# [History on Unicode](http://unicode.org/standard/WhatIsUnicode.html)
#
# [More on Unicode Characters](https://en.wikipedia.org/wiki/List_of_Unicode_characters)

# %%
# print('hi\nthere')
# print('hi\tthere')

pat1 = re.compile('\w+')
pat2 = re.compile('\W+')
found1 = pat1.findall("This is a sentence. !! Isn't it crazy")
found2 = pat2.findall("This is a sentence. !! Isn't it crazy")
print(found1)
print(found2)
# Out:
# ['This', 'is', 'a', 'sentence', 'Isn', 't', 'it', 'crazy']
# [' ', ' ', ' ', '. !! ', "'", ' ', ' ']

# %% [markdown]
# ##### \d - look for any digit 0-9<br/>\D - look for anything that isnt a digit

# %%
pat3 = re.compile('\d+[a-z]{2}')
pat4 = re.compile('\D+')

found3 = pat3.findall('Today is the 11th day of the 7th month. Tomorrow will be 12th')
found4 = pat4.findall('Today is the 11th day of the 7th month. Tomorrow will be 12th')
print(found3)
print(found4)
# Out:
# ['11th', '7th', '12th']
# ['Today is the ', 'th day of the ', 'th month. Tomorrow will be ', 'th']

# %% [markdown]
# ##### \s - look for any white space<br/>\S - look for anything that isnt whitespace

# %%
pat5 = re.compile('\s+')
pat6 = re.compile('\S+')

print('Hello,\nMy name is Shoha')

found5 = pat5.findall('Hello,\nMy name is Shoha')
found6 = pat6.findall('Hello,\nMy name is Shoha')

print(found5)
print(found6)
# Out:
# Hello,
# My name is Shoha
# ['\n', ' ', ' ', ' ']
# ['Hello,', 'My', 'name', 'is', 'Shoha']

# %% [markdown]
# ##### \b - look for boundaries or edges of a word<br/>\B - look for anything that isnt a boundary

# %%
pat7 = re.compile('\bThere\b')
pat8 = re.compile('\BThere\B')


found7 = pat7.findall('HiThereMyNameIsShoha')
found8 = pat8.findall('HiThereMyNameIsShoha')

print(found7)
print(found8)
# Out:
# []
# ['There']

# %% [markdown]
# ### Grouping

# %%
my_string_again = "Max Smith, aaron rodgers, Sam Darnold, LeBron James, Micheal Jordan, Kevin Durant, Patrick McCormick"

# Group of names Regular Expression Compiler
name_pat = re.compile('(?P<first_name>[A-Z][a-zA-Z]+) (?P<last_name>[A-Z][a-zA-Z]+)')
# found = name_pat.findall(my_string_again)
# print(found)

list_of_names = my_string_again.split(',')
print(list_of_names)
for name in list_of_names:
    match = name_pat.match(name.strip())
    if match:
        print(match.group('first_name')) #returns tuple with all groups
    else:
        print('incorrect spelling.. tough')
# Out:
# ['Max Smith', ' aaron rodgers', ' Sam Darnold', ' LeBron James', ' Micheal Jordan', ' Kevin Durant', ' Patrick McCormick']
# Max
# incorrect spelling.. tough
# Sam
# LeBron
# Micheal
# Kevin
# Patrick

# %% [markdown]
# ##### In-class Exercise 2:
#
# Write a function using regular expressions to find the domain name in the given email addresses (and return None for the invalid email addresses)<br><b>HINT: Use '|' for either or</b>

# %%
# You can also use the $ at the end of your compile expression -- this stops the search

#Expected output:
#None
#pocohontas1776@gmail.com
#None
#yourfavoriteband@g6.org
#None

my_emails = ["shohat@codingcodingsummit.orgcom", "pocohontas1776@gmail.com", "helloworld@aol..com",
             "yourfavoriteband@g6.org", "@codingsummit.com"]

pat_emails = re.compile('[a-z][a-z0-9]*@[a-z][a-z0-9]*(.com|.org)$')
print(pat_emails)
for email in my_emails:
    match = pat_emails.match(email)
    if match:
        print(match.group())
# Out:
# re.compile('[a-z][a-z0-9]*@[a-z][a-z0-9]*(.com|.org)$')
# pocohontas1776@gmail.com
# yourfavoriteband@g6.org

# %% [markdown]
# ### Opening a File <br>
#
# <p>Python gives us a couple ways to import files, below are the two used most often.</p>

# %% [markdown]
# ##### open()

# %%
f = open('../files/names.txt')
print(f)
print(type(f))
# Out:
# <_io.TextIOWrapper name='../files/names.txt' mode='r' encoding='cp1252'>
# <class '_io.TextIOWrapper'>

# %% [markdown]
# ##### with open()

# %%
with open('../files/names.txt') as f:
    data = f.read()
    print(data)
    
#this is preferred becasue as soon as you leave the code block, the file is close
# Out:
# Hawkins, Derek	derek@codingtemple.com	(555) 555-5555	Teacher, Coding Temple	@derekhawkins
# Zhai, Mo	mozhai@codingtemple.com	(555) 555-5554	Teacher, Coding Temple
# Johnson, Joe	joejohnson@codingtemple.com		Johson, Joe
# Osterberg, Sven-Erik	governor@norrbotten.co.se		Governor, Norrbotten	@sverik
# , Tim	tim@killerrabbit.com		Enchanter, Killer Rabbit Cave
# Butz, Ryan	ryanb@codingtemple.com	(555) 555-5543	CEO, Coding Temple	@ryanbutz
# Doctor, The	doctor+companion@tardis.co.uk		Time Lord, Gallifrey
# Exampleson, Example	me@example.com	555-555-5552	Example, Example Co.	@example
# Pael, Ripal	ripalp@codingtemple.com	(555) 555-5553	Teacher, Coding Temple	@ripalp
# Vader, Darth	darth-vader@empire.gov	(555) 555-4444	Sith Lord, Galactic Empire	@darthvader
# Fernandez de la Vega Sanz, Maria Teresa	mtfvs@spain.gov		First Deputy Prime Minister, Spanish Gov

# %% [markdown]
# ##### re.match()

# %%
# pattern.match(string) ## First Syntax we learned (Best practice)

# re.match(pattern, string)
match = re.match("Hawkins, Derek", data)
print(match)
# Out:
# <re.Match object; span=(0, 14), match='Hawkins, Derek'>

# %% [markdown]
# ##### re.search()

# %%
#re.search(pattern, string)
print(re.search('[a-z][a-z0-9]*@[a-z][a-z0-9]*(.com|.edu|.org)', data))
# Out:
# <re.Match object; span=(15, 37), match='derek@codingtemple.com'>

# %% [markdown]
# ##### Store the String to a Variable

# %%
pat = input("What would you like to search for?")
found = re.findall(pat, data)
if found:
    print('this is what i found: ', found)
else:
    print('could not find what your looking for..')

# %% [markdown]
# ### In-Class Exercise #3 <br>
#
# <p>Print each persons name and twitter handle, using groups, should look like:</p>
# <p>==============<br>
#    Full Name / Twitter<br>
#    ==============</p>
# Derek Hawkins / @derekhawkins
#  Erik Sven-Osterberg / @sverik
#  Ryan Butz / @ryanbutz
#  Example Exampleson / @example
#  Ripal Pael / @ripalp
#  Darth Vader / @darthvader

# %%
with open("../files/names.txt")as f:
    data = f.readlines()


pattern = re.compile("([A-Z][a-z]+), ([\w -]*)([A-Z][a-z]+).*\s(@[a-zA-Z0-9]+$)")

for person in data:
    match = pattern.search(person)
    if match:
        print('\n', f"{match.group(3)} {match.group(2)}{match.group(1)} / {match.group(4)}")
# Out:
# Failed to start the Kernel.
#
# Jupyter notebook failed to launch.
#
# Cannot read properties of undefined (reading 'makeSettings').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Regex project
#
# Use python to read the file regex_test.txt and print the last name on each line using regular expressions and groups (return None for names with no first and last name, or names that aren't properly capitalized)
#
# ##### Hint: use with open() and readlines()

# %%
"""
Expected Output
Abraham Lincoln
Andrew P Garfield
Connor Milliken
Jordan Alexander Williams
None
None
"""
# Out:
# Failed to start the Kernel.
#
# Jupyter notebook failed to launch.
#
# Cannot read properties of undefined (reading 'makeSettings').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
with open("../inclass/regex_test.txt")as f:
    data = f.readlines()
    
pat2 = re.compile("([A-J][a-zA-W ]+)")


for name in data:
    match = pat2.search(name)
    if match:
        print(match.group())
    else:
        print("None")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\mobak\Documents\Week3\day1\inclass\AdvancedPython_Regular_Expressions_Lecture.ipynb Cell 61 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mobak/Documents/Week3/day1/inclass/AdvancedPython_Regular_Expressions_Lecture.ipynb#ch0000060?line=0'>1</a> with open("../inclass/regex_test.txt")as f:
#       <a href='vscode-notebook-cell:/c%3A/Users/mobak/Documents/Week3/day1/inclass/AdvancedPython_Regular_Expressions_Lecture.ipynb#ch0000060?line=1'>2</a>     data = f.readlines()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mobak/Documents/Week3/day1/inclass/AdvancedPython_Regular_Expressions_Lecture.ipynb#ch0000060?line=3'>4</a> pat2 = re.compile("([A-J][a-zA-W ]+)")
# ...

# %%
# Out:
# Failed to start the Kernel.
#
# Jupyter notebook failed to launch.
#
# Cannot read properties of undefined (reading 'makeSettings').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
